# %% [markdown]
# # Bullshit Bingo

# %% [markdown]
# #### This is a small Bullshit Bingo game to make lectures more fun. Potentially it even helps some to pay more attention.

# %%
class bcolors:
    HEADER = '\033[95m'
    OKBLUE = '\033[94m'
    OKGREEN = '\033[92m'
    WARNING = '\033[93m'
    FAIL = '\033[91m'
    ENDC = '\033[0m'
    BOLD = '\033[1m'
    UNDERLINE = '\033[4m'
words =([])
wg = ["X","X","X","X","X","X","X","X","X"]
e_words=["That's pitty easy","Here we have","And so ont and fort","Everyone does it","You gonna uset a lot","It's normal","These days","Do you want to do dis?","Pythont"] # list of exemplary words

print("\nHi! Are you up for a little "+bcolors.BOLD+"Bullshit-Bingo"+bcolors.ENDC+" game?")
print("\nI have made an exemplary game for you, but you can of course also customize the words.")
print("\nThis is the prefined game:\n\n\t")
print(" "*(15-int((len(e_words[0])/2))), e_words[0]," "*(15-int((len(e_words[0])/2))),"|", " "*(15-int((len(e_words[1])/2))), e_words[1]," "*(15-int((len(e_words[1])/2))),"|", " "*(15-int((len(e_words[2])/2))), e_words[2]," "*(15-int((len(e_words[2])/2))),"\n",
               "---------------------------------------------------------------------------------------------------------\n",
               " "*(15-int((len(e_words[3])/2))), e_words[3]," "*(15-int((len(e_words[3])/2))),"|", " "*(15-int((len(e_words[4])/2))), e_words[4]," "*(15-int((len(e_words[4])/2))),"|", " "*(15-int((len(e_words[5])/2))), e_words[5]," "*(15-int((len(e_words[5])/2))),"\n",
               "---------------------------------------------------------------------------------------------------------\n",
               " "*(15-int((len(e_words[6])/2))), e_words[6]," "*(15-int((len(e_words[6])/2))),"|", " "*(15-int((len(e_words[7])/2))), e_words[7]," "*(15-int((len(e_words[7])/2))),"|", " "*(15-int((len(e_words[8])/2))), e_words[8]," "*(15-int((len(e_words[8])/2))),"\n")

choice=False

while choice!=True:
    choice=input("\nDo you wanna play with the predefined list? (y/n)\t")
    if choice == "n": # custom game

        while len(words) != 9:
            words = input('\nOkay, write down your 9 "Bullshit-Bingo"words seperated by comma: \n').split(',')
            print()
        print("\nGood job! Your table looks like this now:")

        # I first thought that I can make a nice looking table with the prettytable library, but as far as I know single values couldnt be changed there.So thats why I had o build this spaced table by myself..
        bingo_table=[" "*(14-int((len(words[0])/2))), words[0]," "*(15-int((len(words[0])/2))),"|", " "*(15-int((len(words[1])/2))), words[1]," "*(15-int((len(words[1])/2))),"|", " "*(15-int((len(words[2])/2))), words[2]," "*(15-int((len(words[2])/2))),"\n",
              "-----------------------------------------------------------------------------------------\n",
              " "*(15-int((len(words[3])/2))), words[3]," "*(15-int((len(words[3])/2))),"|", " "*(15-int((len(words[4])/2))), words[4]," "*(15-int((len(words[4])/2))),"|", " "*(15-int((len(words[5])/2))), words[5]," "*(15-int((len(words[5])/2))),"\n",
              "-----------------------------------------------------------------------------------------\n",
              " "*(15-int((len(words[6])/2))), words[6]," "*(15-int((len(words[6])/2))),"|", " "*(15-int((len(words[7])/2))), words[7]," "*(15-int((len(words[7])/2))),"|", " "*(15-int((len(words[8])/2))), words[8]," "*(15-int((len(words[8])/2))),"\n"]
        print(''.join(bingo_table))

        bingo=False
        
        print("Now whenever one of the words is named for the first time just write down the name.\n")

        while bingo == False:

        # let the user make the input as long as he hasnt three in a row
            named_word=input("\nWhat was the word?\t")
            if named_word == words[0]:
                words[0] = "X"
            elif named_word == words[1]:
                words[1] = "X"
            elif named_word == words[2]:
                words[2] = "X"
            elif named_word == words[3]:
                words[3] = "X"
            elif named_word == words[4]:
                words[4] = "X"
            elif named_word == words[5]:
                words[5] = "X"
            elif named_word == words[6]:
                words[6] = "X"
            elif named_word == words[7]:
                words[7] = "X"
            elif named_word == words[8]:
                words[8] = "X"

            print("\nHere is your new Bingo-table!\n")
            bingo_table=[" "*(14-int((len(words[0])/2))), words[0]," "*(15-int((len(words[0])/2))),"|", " "*(15-int((len(words[1])/2))), words[1]," "*(15-int((len(words[1])/2))),"|", " "*(15-int((len(words[2])/2))), words[2]," "*(15-int((len(words[2])/2))),"\n",
              "-----------------------------------------------------------------------------------------\n",
              " "*(15-int((len(words[3])/2))), words[3]," "*(15-int((len(words[3])/2))),"|", " "*(15-int((len(words[4])/2))), words[4]," "*(15-int((len(words[4])/2))),"|", " "*(15-int((len(words[5])/2))), words[5]," "*(15-int((len(words[5])/2))),"\n",
              "-----------------------------------------------------------------------------------------\n",
              " "*(15-int((len(words[6])/2))), words[6]," "*(15-int((len(words[6])/2))),"|", " "*(15-int((len(words[7])/2))), words[7]," "*(15-int((len(words[7])/2))),"|", " "*(15-int((len(words[8])/2))), words[8]," "*(15-int((len(words[8])/2))),"\n"]
            print(''.join(bingo_table))

        # check if the player wins
            if (words[0]==wg[0] and words[1]==wg[1] and words[2]==wg[2]) or \
            (words[3]==wg[3] and words[4]==wg[4] and words[5]==wg[5]) or \
            (words[6]==wg[6] and words[7]==wg[7] and words[8]==wg[8]) or \
            (words[0]==wg[0] and words[3]==wg[3] and words[6]==wg[6]) or \
            (words[1]==wg[1] and words[4]==wg[4] and words[7]==wg[7]) or \
            (words[2]==wg[2] and words[5]==wg[5] and words[8]==wg[8]) or \
            (words[0]==wg[0] and words[4]==wg[4] and words[8]==wg[8]) or \
            (words[2]==wg[2] and words[4]==wg[4] and words[6]==wg[6]):
                print("\n\n\t\t"+bcolors.HEADER+"B I N G O !"+bcolors.ENDC+"\n\t\t  You win")
                bingo=True
                choice=True

    elif choice == "y": # predefined game
        
        bingo=False
        
        print("Now whenever one of the words is named for the first time just write down the name.\n")
        
        while bingo == False:

        # let the user make the input as long as he hasnt three in a row
        
            named_word=input("\nWhat was the word?\t")
            
            if named_word == e_words[0]:
                e_words[0] = "X"
            elif named_word == e_words[1]:
                e_words[1] = "X"
            elif named_word == e_words[2]:
                e_words[2] = "X"
            elif named_word == e_words[3]:
                e_words[3] = "X"
            elif named_word == e_words[4]:
                e_words[4] = "X"
            elif named_word == e_words[5]:
                e_words[5] = "X"
            elif named_word == e_words[6]:
                e_words[6] = "X"
            elif named_word == e_words[7]:
                e_words[7] = "X"
            elif named_word == e_words[8]:
                e_words[8] = "X"

            print("\nHere is your new Bingo-table!\n")
            
            bingo_table=([" "*(14-int((len(e_words[0])/2))), e_words[0]," "*(15-int((len(e_words[0])/2))),"|", " "*(15-int((len(e_words[1])/2))), e_words[1]," "*(15-int((len(e_words[1])/2))),"|", " "*(15-int((len(e_words[2])/2))), e_words[2]," "*(15-int((len(e_words[2])/2))),"\n",
               "-----------------------------------------------------------------------------------------\n",
               " "*(15-int((len(e_words[3])/2))), e_words[3]," "*(15-int((len(e_words[3])/2))),"|", " "*(15-int((len(e_words[4])/2))), e_words[4]," "*(15-int((len(e_words[4])/2))),"|", " "*(15-int((len(e_words[5])/2))), e_words[5]," "*(15-int((len(e_words[5])/2))),"\n",
               "-----------------------------------------------------------------------------------------\n",
               " "*(15-int((len(e_words[6])/2))), e_words[6]," "*(15-int((len(e_words[6])/2))),"|", " "*(15-int((len(e_words[7])/2))), e_words[7]," "*(15-int((len(e_words[7])/2))),"|", " "*(15-int((len(e_words[8])/2))), e_words[8]," "*(15-int((len(e_words[8])/2))),"\n"])
            print(''.join(bingo_table))

        # check if the player wins
            if (e_words[0]==wg[0] and e_words[1]==wg[1] and e_words[2]==wg[2]) or \
            (e_words[3]==wg[3] and e_words[4]==wg[4] and e_words[5]==wg[5]) or \
            (e_words[6]==wg[6] and e_words[7]==wg[7] and e_words[8]==wg[8]) or \
            (e_words[0]==wg[0] and e_words[3]==wg[3] and e_words[6]==wg[6]) or \
            (e_words[1]==wg[1] and e_words[4]==wg[4] and e_words[7]==wg[7]) or \
            (e_words[2]==wg[2] and e_words[5]==wg[5] and e_words[8]==wg[8]) or \
            (e_words[0]==wg[0] and e_words[4]==wg[4] and e_words[8]==wg[8]) or \
            (e_words[2]==wg[2] and e_words[4]==wg[4] and e_words[6]==wg[6]):
                print("\n\n\t\t"+bcolors.HEADER+"B I N G O !"+bcolors.ENDC+"\n\t\t  You win")
                bingo=True
                choice=True

    else:
        print("Common, it can't be that hard to type y or n, or?")
print("\nThanks for playing")
import time
import webbrowser
time.sleep(5)
webbrowser.open('https://media.giphy.com/media/xT5LMRJ4n1xaQeNz6E/giphy.gif')
time.sleep(8)
webbrowser.open('https://media.giphy.com/media/3o85fYKy0R91nLbtte/giphy.gif')
# Out:
# Hi! Are you up for a little Bullshit-Bingo game?
#
# I have made an exemplary game for you, but you can of course also customize the words.
#
# This is the prefined game:
#
#
#         That's pitty easy         |           Here we have           |        And so ont and fort
#  ---------------------------------------------------------------------------------------------------------
#          Everyone does it         |       You gonna uset a lot       |            It's normal
#  ---------------------------------------------------------------------------------------------------------
#             These days            |      Do you want to do dis?      |              Pythont
